# %% [markdown]
# # Model for Predicting if the person will buy insurance or not  ~

# %% [markdown]
# ### Libraries required for building model

# %%
import numpy as np
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras

# %%
df = pd.read_csv("OneDrive/Documents/27oct/Deep_learning/gradient_descent/Insurance_data.txt")

# %%
df.head(5)
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %% [markdown]
# #### After importing the data now splitting the data for train test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df[['age','affordibility']],df.bought_insurance, test_size = 0.2, 
                                                    random_state=25)

# %% [markdown]
# #### Now Scaling data so it lies in the range  0 to 1

# %%
X_train_scaled = X_train.copy()
X_train_scaled['age'] = X_train_scaled['age']/ 100

X_test_scaled = X_test.copy()
X_test_scaled['age'] = X_test_scaled['age']/ 100

# %%
X_train_scaled.head()
# Out:
#      age  affordibility
# 0   0.22              1
# 13  0.29              0
# 6   0.55              0
# 17  0.58              1
# 24  0.50              1

# %% [markdown]
# ### Defining Sigmoid function and  Prediction function

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def predict(age,affordibility,w1,w2,bias):
    weighted_sum = w1*age + w2*affordibility + bias
    return sigmoid(weighted_sum)

# %% [markdown]
# ### Defining and loss function and gradient descent function

# %%
def logg_loss(y_true, y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
def gradient_descent(age, affordibility, y_true, epochs,loss_thresold):
    w1 = w2 = 0.8
    bias = 0
    rate = 0.5
    n = len(age)
    
    for i in range(epochs):
        y_predicted = predict(age,affordibility,w1,w2,bias)       
        
        loss = logg_loss(y_true,y_predicted)
        
        w1d = (1/n)*np.dot(np.transpose(age),(y_predicted-y_true))
        w2d = (1/n)*np.dot(np.transpose(affordibility),(y_predicted-y_true))
        
        biasd = np.mean(y_predicted-y_true)
        
        w1 = w1 - rate * w1d
        w2 = w2 - rate * w2d
        
        bias = bias - rate * biasd
        
        print(f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
        
        if loss<=loss_thresold:
            break
    
    return w1,w2,bias

# %% [markdown]
# ## Now Running the model

# %%
w1, w2 , b = gradient_descent(X_train_scaled['age'],X_train_scaled['affordibility'],y_train, 1000,0.4631)
# Out:
# Epoch:0, w1:0.7828446734485206, w2:0.7636405390041273, bias:-0.09494263968408463, loss:0.6851666201630279
# Epoch:1, w1:0.7708580320474032, w2:0.7356444439190558, bias:-0.17700639558771908, loss:0.6655072828256926
# Epoch:2, w1:0.7633995497967453, w2:0.715018515055488, bias:-0.24780700492554342, loss:0.6513608407006541
# Epoch:3, w1:0.7598232702580356, w2:0.7007183108768832, bias:-0.3089556706770322, loss:0.6412122308421205
# Epoch:4, w1:0.759520802798041, w2:0.6917349427179741, bias:-0.36195844759736767, loss:0.6338833099215265
# Epoch:5, w1:0.7619451844510355, w2:0.6871466495241293, bias:-0.4081621191512502, loss:0.6285029244141136
# Epoch:6, w1:0.7666203049451846, w2:0.6861426222604683, bias:-0.448734496719481, loss:0.6244502747549486
# Epoch:7, w1:0.7731410104717861, w2:0.6880282422488067, bias:-0.4846665590330687, loss:0.6212946743999094
# Epoch:8, w1:0.7811679992682435, w2:0.6922194558389124, bias:-0.516786526168311, loss:0.6187430340630082
# Epoch:9, w1:0.7904203262669859, w2:0.6982317372929181, bias:-0.5457791858297529, loss:0.616598608943337
# Epoch:10, w1:0.8006672412849489, w2:0.7056670701234387, bias:-0.5722064406816835, loss:0.6147305702246247
# Epoch:11, w1:0.8117203132248997, w2:0.7142009068414352, bias:-0.5965268898636356, loss:0.6130524562822605
# Epoch:12, w1:0.8234263014183336, w2:0.7235701105827691, bias:-0.6191134172194217, loss:0.6115073245122414
# Epoch:13, w1:0.835660945646365, w2:0.7335623059562751, bias:-0.6402684336566925, loss:0.6100577115800215
# Epoch:14, w1:0.8483236876388334, w2:0.7440067419310356, bias:-0.6602367853501253, loss:0.6086789343006817
# Epoch:15, w1:0.8613332575585939, w2:0.7547666004054767, bias:-0.6792165171948839, loss:0.6073546614996611
# Epoch:16, w1:0.8746240254847668, w2:0.7657326061114405, bias:-0.6973677522026245, loss:0.606074006696922
# Epoch:17, w1:0.8881430094975417, w2:0.776817766608755, bias:-0.7148199613259237, loss:0.6048296285362942
# Epoch:18, w1:0.9018474364011017, w2:0.7879530713093915, bias:-0.7316778831282309, loss:0.6036164939475732
# Epoch:19, w1:0.9157027614190386, w2:0.7990839918237321, bias:-0.7480263249587985, loss:0.6024310747738503
# Epoch:20, w1:0.9296810655180637, w2:0.8101676446404141, bias:-0.7639340456350067, loss:0.6012708267879555
# Epoch:21, w1:0.9437597613496179, w2:0.8211704970293822, bias:-0.779456888603285, loss:0.6001338521479314
# Epoch:22, w1:0.9579205501744825, w2:0.8320665159641739, bias:-0.7946403062651617, loss:0.5990186807673584
# Epoch:23, w1:0.9721485821590128, w2:0.8428356768337506, bias:-0.8095213914189551, loss:0.597924128660278
# Epoch:24, w1:0.9864317810180222, w2:0.8534627634375367, bias:-0.824130510687673, loss:0.5968492060637596
# Epoch:25, w1:1.0007603011990307, w2:0.8639364032469868, bias:-0.838492617145323, loss:0.5957930577316902
# Epoch:26, w1:1.0151260917957088, w2:0.8742482923525093, bias:-0.8526283047363155, loss:0.5947549240157426
# Epoch:27, w1:1.029522546308117, w2:0.884392573141105, bias:-0.8665546550842234, loss:0.5937341153788958
# Epoch:28, w1:1.0439442213956103, w2:0.8943653348262574, bias:-0.8802859174979932, loss:0.5927299955926523
# Epoch:29, w1:1.058386611043777, w2:0.904164212723025, bias:-0.8938340550348868, loss:0.5917419705525347
# Epoch:30, w1:1.0728459652204285, w2:0.9137880668484691, bias:-0.9072091830462572, loss:0.5907694807333449
# Epoch:31, w1:1.0873191442395405, w2:0.9232367242219327, bias:-0.9204199214390512, loss:0.5898119960070801
# Epoch:32, w1:1.1018035017804677, w2:0.9325107723038355, bias:-0.9334736777017981, loss:0.5888690119989688
# Epoch:33, w1:1.1162967909010137, w2:0.9416113934814835, bias:-0.9463768743776473, loss:0.5879400474490527
# Epoch:34, w1:1.1307970885014458, w2:0.9505402324983933, bias:-0.9591351319618269, loss:0.5870246422351045
# Epoch:35, w1:1.1453027345949804, w2:0.9592992903220854, bias:-0.9717534160287026, loss:0.5861223558342269
# Epoch:36, w1:1.15981228346144, w2:0.9678908392295298, bias:-0.9842361556504328, loss:0.5852327660788977
# Epoch:37, w1:1.1743244643393993, w2:0.9763173549205962, bias:-0.9965873387709183, loss:0.5843554681138966
# Epoch:38, w1:1.1888381497762222, w2:0.9845814622975066, bias:-1.0088105890774166, loss:0.583490073493222
# Epoch:39, w1:1.2033523301275308, w2:0.9926858922123847, bias:-1.0209092280131284, loss:0.5826362093772607
# Epoch:40, w1:1.2178660929960339, w2:1.000633447017784, bias:-1.0328863248532856, loss:0.5817935178041217
# Epoch:41, w1:1.2323786066388616, w2:1.0084269731824773, bias:-1.0447447371894254, loss:0.5809616550178871
# Epoch:42, w1:1.2468891065643681, w2:1.0160693395776423, bias:-1.056487143703274, loss:0.5801402908422613
# Epoch:43, w1:1.26139688469315, w2:1.02356342031363, bias:-1.0681160707402242, loss:0.5793291080918057
# Epoch:44, w1:1.2759012805813597, w2:1.030912081228163, bias:-1.0796339138945559, loss:0.5785278020153679
# Epoch:45, w1:1.2904016743033013, w2:1.0381181693038815, bias:-1.0910429555796766, loss:0.5777360797678802
# Epoch:46, w1:1.30489748066964, w2:1.045184504435238, bias:-1.1023453793650668, loss:0.5769536599077364
# Epoch:47, w1:1.319388144521202, w2:1.0521138730788027, bias:-1.1135432817078996, loss:0.5761802719176302
# Epoch:48, w1:1.333873136889429, w2:1.058909023412598, bias:-1.124638681583959, loss:0.5754156557471961
# Epoch:49, w1:1.348351951855545, w2:1.0655726617036017, bias:-1.1356335284234886, loss:0.5746595613760855
# Epoch:50, w1:1.3628241039734001, w2:1.0721074496416108, bias:-1.1465297086781217, loss:0.5739117483963284
# Epoch:51, w1:1.3772891261473956, w2:1.078516002445088, bias:-1.1573290512812369, loss:0.5731719856129712
# Epoch:52, w1:1.3917465678781078, w2:1.0848008875827329, bias:-1.1680333322128222, loss:0.5724400506620856
# Epoch:53, w1:1.4061959938052946, w2:1.0909646239851485, bias:-1.1786442783387572, loss:0.5717157296453236
# Epoch:54, w1:1.4206369824916631, w2:1.0970096816456052, bias:-1.1891635706613308, loss:0.5709988167802514
# Epoch:55, w1:1.4350691254017964, w2:1.102938481528701, bias:-1.1995928470912198, loss:0.5702891140657467
# Epoch:56, w1:1.4494920260394955, w2:1.1087533957216484, bias:-1.209933704829762, loss:0.5695864309617821
# Epoch:57, w1:1.463905299213911, w2:1.1144567477757237, bias:-1.2201877024331695, loss:0.5688905840829549
# Epoch:58, w1:1.4783085704105756, w2:1.1200508131957316, bias:-1.23035636161648, loss:0.5682013969051544
# Epoch:59, w1:1.4927014752480547, w2:1.1255378200436315, bias:-1.2404411688439232, loss:0.5675186994847857
# Epoch:60, w1:1.5070836590046475, w2:1.130919949629149, bias:-1.2504435767434061, loss:0.5668423281899974
# Epoch:61, w1:1.5214547762025596, w2:1.136199337265582, bias:-1.2603650053756141, loss:0.5661721254433871
# Epoch:62, w1:1.5358144902393756, w2:1.1413780730733323, bias:-1.2702068433824047, loss:0.5655079394756759
# Epoch:63, w1:1.5501624730585977, w2:1.1464582028171906, bias:-1.2799704490344919, loss:0.5648496240898732
# Epoch:64, w1:1.5644984048525876, w2:1.1514417287662078, bias:-1.2896571511946413, loss:0.5641970384354709
# Epoch:65, w1:1.5788219737924998, w2:1.15633061056725, bias:-1.2992682502095545, loss:0.5635500467922251
# Epoch:66, w1:1.5931328757808192, w2:1.1611267661251612, bias:-1.3088050187411602, loss:0.5629085183631066
# Epoch:67, w1:1.6074308142229345, w2:1.1658320724839244, bias:-1.3182687025460527, loss:0.5622723270760166
# Epoch:68, w1:1.621715499814842, w2:1.170448366704396, bias:-1.327660521210216, loss:0.5616413513938837
# Epoch:69, w1:1.6359866503446072, w2:1.1749774467351433, bias:-1.3369816688448743, loss:0.5610154741327769
# Epoch:70, w1:1.6502439905056512, w2:1.179421072273683, bias:-1.3462333147482712, loss:0.560394582287681
# Epoch:71, w1:1.6644872517202705, w2:1.1837809656160332, bias:-1.3554166040373268, loss:0.559778566865601
# Epoch:72, w1:1.6787161719720887, w2:1.188058812492993, bias:-1.3645326582524426, loss:0.5591673227256754
# Epoch:73, w1:1.6929304956463658, w2:1.1922562628919622, bias:-1.3735825759381644, loss:0.5585607484259923
# Epoch:74, w1:1.707129973377276, w2:1.1963749318634331, bias:-1.3825674332019662, loss:0.557958746076814
# Epoch:75, w1:1.7213143619014166, w2:1.2004164003115458, bias:-1.3914882842530503, loss:0.5573612211999355
# Epoch:76, w1:1.7354834239169352, w2:1.204382215768305, bias:-1.4003461619227624, loss:0.5567680825939061
# Epoch:77, w1:1.7496369279477584, w2:1.2082738931512198, bias:-1.4091420781679775, loss:0.5561792422048599
# Epoch:78, w1:1.763774648212489, w2:1.212092915504259, bias:-1.4178770245586145, loss:0.5555946150027149
# Epoch:79, w1:1.7778963644976058, w2:1.2158407347221218, bias:-1.426551972750277, loss:0.5550141188625037
# Epoch:80, w1:1.7920018620346516, w2:1.2195187722579037, bias:-1.4351678749428827, loss:0.5544376744506182
# Epoch:81, w1:1.806090931381141, w2:1.223128419814302, bias:-1.4437256643260388, loss:0.5538652051157521
# Epoch:82, w1:1.8201633683049567, w2:1.2266710400185574, bias:-1.4522262555118255, loss:0.5532966367843417
# Epoch:83, w1:1.834218973672031, w2:1.2301479670813689, bias:-1.4606705449555812, loss:0.5527318978603097
# Epoch:84, w1:1.8482575533371364, w2:1.233560507440044, bias:-1.4690594113652167, loss:0.5521709191289271
# Epoch:85, w1:1.862278918037628, w2:1.2369099403861736, bias:-1.4773937160995372, loss:0.5516136336646167
# Epoch:86, w1:1.8762828832899974, w2:1.2401975186781358, bias:-1.485674303556007, loss:0.5510599767425309
# Epoch:87, w1:1.890269269289114, w2:1.2434244691387417, bias:-1.4939020015483524, loss:0.5505098857537379
# Epoch:88, w1:1.9042379008100394, w2:1.2465919932383496, bias:-1.5020776216743745, loss:0.5499633001238688
# Epoch:89, w1:1.9181886071123113, w2:1.249701267663771, bias:-1.5102019596743073, loss:0.5494201612350715
# Epoch:90, w1:1.9321212218466035, w2:1.2527534448733018, bias:-1.5182757957800443, loss:0.548880412351135
# Epoch:91, w1:1.946035582963674, w2:1.2557496536382031, bias:-1.5262998950555293, loss:0.5483439985456496
# Epoch:92, w1:1.9599315326255193, w2:1.2586909995709648, bias:-1.534275007728592, loss:0.5478108666330703
# Epoch:93, w1:1.9738089171186608, w2:1.2615785656406704, bias:-1.542201869514499, loss:0.5472809651025647
# Epoch:94, w1:1.987667586769491, w2:1.2644134126757895, bias:-1.5500812019314663, loss:0.5467542440545269
# Epoch:95, w1:2.0015073958616156, w2:1.2671965798547098, bias:-1.5579137126083815, loss:0.5462306551396442
# Epoch:96, w1:2.0153282025551236, w2:1.26992908518432, bias:-1.5657000955849603, loss:0.5457101515004079
# Epoch:97, w1:2.0291298688077317, w2:1.2726119259669502, bias:-1.5734410316045602, loss:0.5451926877149699
# Epoch:98, w1:2.0429122602977423, w2:1.2752460792559674, bias:-1.5811371883998622, loss:0.5446782197432432
# Epoch:99, w1:2.0566752463487608, w2:1.2778325023003172, bias:-1.5887892209716232, loss:0.5441667048751518
# Epoch:100, w1:2.070418699856125, w2:1.2803721329783002, bias:-1.5963977718606963, loss:0.5436581016809445
# Epoch:101, w1:2.0841424972149922, w2:1.2828658902208614, bias:-1.6039634714135038, loss:0.5431523699634823
# Epoch:102, w1:2.0978465182500385, w2:1.2853146744246642, bias:-1.611486938041149, loss:0.54264947071242
# Epoch:103, w1:2.111530646146727, w2:1.2877193678552172, bias:-1.6189687784723394, loss:0.5421493660602015
# Epoch:104, w1:2.1251947673840985, w2:1.2900808350403126, bias:-1.626409588000291, loss:0.5416520192397958
# Epoch:105, w1:2.138838771669043, w2:1.2923999231540266, bias:-1.6338099507237784, loss:0.541157394544101
# Epoch:106, w1:2.1524625518720133, w2:1.294677462391534, bias:-1.6411704397824904, loss:0.5406654572869439
# Epoch:107, w1:2.1660660039641404, w2:1.2969142663349702, bias:-1.6484916175868412, loss:0.5401761737656183
# Epoch:108, w1:2.179649026955713, w2:1.2991111323105797, bias:-1.6557740360423892, loss:0.5396895112248875
# Epoch:109, w1:2.193211522835986, w2:1.3012688417373768, bias:-1.6630182367690065, loss:0.5392054378224007
# Epoch:110, w1:2.20675339651428, w2:1.303388160467538, bias:-1.6702247513149382, loss:0.5387239225954602
# Epoch:111, w1:2.220274555762344, w2:1.3054698391187458, bias:-1.6773941013658864, loss:0.5382449354290845
# Epoch:112, w1:2.23377491115794, w2:1.3075146133986904, bias:-1.684526798949252, loss:0.5377684470253169
# Epoch:113, w1:2.2472543760296255, w2:1.309523204421933, bias:-1.6916233466336597, loss:0.5372944288737262
# Epoch:114, w1:2.2607128664026988, w2:1.3114963190193332, bias:-1.698684237723889, loss:0.536822853223054
# Epoch:115, w1:2.27415030094628, w2:1.313434650040228, bias:-1.7057099564513354, loss:0.5363536930539587
# Epoch:116, w1:2.2875666009214957, w2:1.315338876647555, bias:-1.7127009781601112, loss:0.535886922052814
# Epoch:117, w1:2.3009616901307433, w2:1.3172096646060998, bias:-1.7196577694889055, loss:0.53542251458652
# Epoch:118, w1:2.3143354948680055, w2:1.3190476665640445, bias:-1.7265807885487068, loss:0.5349604456782836
# Epoch:119, w1:2.327687943870191, w2:1.3208535223279934, bias:-1.7334704850965001, loss:0.5345006909843332
# Epoch:120, w1:2.3410189682694718, w2:1.3226278591316403, bias:-1.7403273007050368, loss:0.5340432267715228
# Epoch:121, w1:2.3543285015465982, w2:1.3243712918982422, bias:-1.7471516689287807, loss:0.5335880298958
# Epoch:122, w1:2.3676164794851644, w2:1.3260844234970584, bias:-1.7539440154661265, loss:0.5331350777814945
# Epoch:123, w1:2.3808828401268003, w2:1.3277678449939083, bias:-1.7607047583179853, loss:0.5326843484014001
# Epoch:124, w1:2.3941275237272723, w2:1.3294221358959997, bias:-1.7674343079428283, loss:0.5322358202576144
# Epoch:125, w1:2.4073504727134645, w2:1.3310478643911718, bias:-1.7741330674082783, loss:0.5317894723631091
# Epoch:126, w1:2.4205516316412257, w2:1.3326455875816958, bias:-1.7808014325393369, loss:0.5313452842240016
# Epoch:127, w1:2.4337309471540562, w2:1.3342158517127705, bias:-1.787439792063329, loss:0.5309032358224969
# Epoch:128, w1:2.4468883679426203, w2:1.335759192395848, bias:-1.7940485277516491, loss:0.5304633076004782
# Epoch:129, w1:2.4600238447050575, w2:1.3372761348269195, bias:-1.8006280145583864, loss:0.5300254804437174
# Epoch:130, w1:2.473137330108084, w2:1.3387671939998866, bias:-1.8071786207559075, loss:0.5295897356666802
# Epoch:131, w1:2.486228778748854, w2:1.3402328749151449, bias:-1.813700708067472, loss:0.5291560549979061
# Epoch:132, w1:2.4992981471175755, w2:1.3416736727834957, bias:-1.8201946317969533, loss:0.5287244205659369
# Epoch:133, w1:2.512345393560853, w2:1.3430900732255069, bias:-1.826660740955734, loss:0.528294814885776
# Epoch:134, w1:2.5253704782457485, w2:1.344482552466432, bias:-1.8330993783868497, loss:0.5278672208458519
# Epoch:135, w1:2.5383733631245375, w2:1.3458515775268003, bias:-1.8395108808864418, loss:0.5274416216954741
# Epoch:136, w1:2.5513540119001505, w2:1.3471976064087865, bias:-1.8458955793225904, loss:0.5270180010327544
# Epoch:137, w1:2.5643123899922804, w2:1.348521088278461, bias:-1.852253798751587, loss:0.526596342792982
# Epoch:138, w1:2.5772484645041422, w2:1.349822463644025, bias:-1.8585858585317108, loss:0.5261766312374285
# Epoch:139, w1:2.590162204189873, w2:1.3511021645301273, bias:-1.8648920724345661, loss:0.5257588509425727
# Epoch:140, w1:2.6030535794225513, w2:1.352360614648361, bias:-1.871172748754043, loss:0.5253429867897236
# Epoch:141, w1:2.615922562162831, w2:1.3535982295640319, bias:-1.8774281904129544, loss:0.5249290239550282
# Epoch:142, w1:2.6287691259281685, w2:1.354815416859289, bias:-1.8836586950674072, loss:0.5245169478998499
# Epoch:143, w1:2.641593245762637, w2:1.3560125762927082, bias:-1.8898645552089604, loss:0.5241067443615027
# Epoch:144, w1:2.654394898207309, w2:1.357190099955412, bias:-1.8960460582646212, loss:0.523698399344326
# Epoch:145, w1:2.6671740612711967, w2:1.358348372423812, bias:-1.902203486694734, loss:0.5232918991110898
# Epoch:146, w1:2.6799307144027447, w2:1.3594877709090518, bias:-1.9083371180888067, loss:0.5228872301747151
# Epoch:147, w1:2.69266483846185, w2:1.360608665403235, bias:-1.914447225259327, loss:0.5224843792902981
# Epoch:148, w1:2.705376415692412, w2:1.3617114188225097, bias:-1.920534076333612, loss:0.5220833334474283
# Epoch:149, w1:2.718065429695392, w2:1.362796387147089, bias:-1.9265979348437408, loss:0.5216840798627851
# Epoch:150, w1:2.730731865402375, w2:1.363863919558278, bias:-1.9326390598146101, loss:0.5212866059730081
# Epoch:151, w1:2.743375709049624, w2:1.36491435857258, bias:-1.938657705850161, loss:0.5208908994278246
# Epoch:152, w1:2.755996948152611, w2:1.3659480401729494, bias:-1.944654123217815, loss:0.52049694808343
# Epoch:153, w1:2.768595571481027, w2:1.366965293937261, bias:-1.950628557931162, loss:0.5201047399961061
# Epoch:154, w1:2.7811715690342433, w2:1.3679664431640592, bias:-1.9565812518309422, loss:0.5197142634160741
# Epoch:155, w1:2.793724932017234, w2:1.3689518049956526, bias:-1.9625124426643579, loss:0.5193255067815671
# Epoch:156, w1:2.8062556528169345, w2:1.3699216905386147, bias:-1.968422364162754, loss:0.5189384587131204
# Epoch:157, w1:2.8187637249790356, w2:1.3708764049817528, bias:-1.9743112461177068, loss:0.5185531080080655
# Epoch:158, w1:2.8312491431852034, w2:1.3718162477116036, bias:-1.9801793144555526, loss:0.5181694436352237
# Epoch:159, w1:2.843711903230713, w2:1.3727415124255116, bias:-1.986026791310396, loss:0.5177874547297897
# Epoch:160, w1:2.8561520020024935, w2:1.3736524872423486, bias:-1.9918538950956282, loss:0.5174071305884017
# Epoch:161, w1:2.8685694374575665, w2:1.3745494548109267, bias:-1.9976608405739926, loss:0.5170284606643842
# Epoch:162, w1:2.880964208601882, w2:1.3754326924161602, bias:-2.003447838926226, loss:0.5166514345631648
# Epoch:163, w1:2.8933363154695364, w2:1.3763024720830246, bias:-2.0092150978183105, loss:0.5162760420378534
# Epoch:164, w1:2.9056857591023633, w2:1.3771590606783677, bias:-2.014962821467366, loss:0.5159022729849781
# Epoch:165, w1:2.9180125415298988, w2:1.3780027200106173, bias:-2.020691210706212, loss:0.5155301174403751
# Epoch:166, w1:2.9303166657497024, w2:1.3788337069274368, bias:-2.026400463046631, loss:0.5151595655752227
# Epoch:167, w1:2.9425981357080366, w2:1.379652273411373, bias:-2.032090772741361, loss:0.5147906076922172
# Epoch:168, w1:2.954856956280892, w2:1.3804586666735439, bias:-2.0377623308448407, loss:0.5144232342218847
# Epoch:169, w1:2.9670931332553536, w2:1.3812531292454078, bias:-2.0434153252727447, loss:0.514057435719021
# Epoch:170, w1:2.9793066733113, w2:1.3820358990686592, bias:-2.049049940860325, loss:0.5136932028592598
# Epoch:171, w1:2.9914975840034312, w2:1.3828072095832933, bias:-2.0546663594195884, loss:0.5133305264357596
# Epoch:172, w1:3.003665873743621, w2:1.3835672898138782, bias:-2.060264759795341, loss:0.5129693973560093
# Epoch:173, w1:3.015811551783576, w2:1.3843163644540784, bias:-2.0658453179201133, loss:0.5126098066387436
# Epoch:174, w1:3.027934628197815, w2:1.3850546539494633, bias:-2.0714082068679986, loss:0.5122517454109665
# Epoch:175, w1:3.0400351138669404, w2:1.3857823745786446, bias:-2.0769535969074266, loss:0.5118952049050814
# Epoch:176, w1:3.052113020461217, w2:1.3864997385327757, bias:-2.0824816555528924, loss:0.511540176456118
# Epoch:177, w1:3.0641683604244356, w2:1.3872069539934495, bias:-2.0879925476156647, loss:0.5111866514990574
# Epoch:178, w1:3.076201146958067, w2:1.3879042252090321, bias:-2.0934864352534976, loss:0.5108346215662494
# Epoch:179, w1:3.088211394005695, w2:1.3885917525694647, bias:-2.098963478019363, loss:0.5104840782849203
# Epoch:180, w1:3.100199116237727, w2:1.3892697326795678, bias:-2.1044238329092275, loss:0.5101350133747652
# Epoch:181, w1:3.1121643290363736, w2:1.389938358430881, bias:-2.1098676544088932, loss:0.5097874186456237
# Epoch:182, w1:3.124107048480894, w2:1.3905978190720694, bias:-2.115295094539922, loss:0.5094412859952372
# Epoch:183, w1:3.136027291333103, w2:1.3912483002779275, bias:-2.1207063029046624, loss:0.5090966074070815
# Epoch:184, w1:3.1479250750231333, w2:1.3918899842170132, bias:-2.1261014267304015, loss:0.5087533749482728
# Epoch:185, w1:3.1598004176354495, w2:1.3925230496179386, bias:-2.131480610912652, loss:0.5084115807675479
# Epoch:186, w1:3.171653337895107, w2:1.393147671834349, bias:-2.1368439980576026, loss:0.5080712170933107
# Epoch:187, w1:3.1834838551542552, w2:1.3937640229086157, bias:-2.142191728523744, loss:0.5077322762317467
# Epoch:188, w1:3.1952919893788763, w2:1.394372271634273, bias:-2.1475239404626847, loss:0.5073947505649993
# Epoch:189, w1:3.207077761135758, w2:1.3949725836172244, bias:-2.1528407698591816, loss:0.5070586325494112
# Epoch:190, w1:3.218841191579697, w2:1.3955651213357445, bias:-2.158142350570396, loss:0.5067239147138216
# Epoch:191, w1:3.230582302440923, w2:1.3961500441993036, bias:-2.1634288143643903, loss:0.5063905896579222
# Epoch:192, w1:3.24230111601275, w2:1.3967275086062374, bias:-2.168700290957885, loss:0.5060586500506677
# Epoch:193, w1:3.2539976551394374, w2:1.397297668000289, bias:-2.1739569080532912, loss:0.5057280886287417
# Epoch:194, w1:3.265671943204269, w2:1.3978606729260454, bias:-2.1791987913750264, loss:0.5053988981950684
# Epoch:195, w1:3.277324004117839, w2:1.3984166710832917, bias:-2.1844260647051406, loss:0.5050710716173806
# Epoch:196, w1:3.2889538623065433, w2:1.398965807380307, bias:-2.1896388499182553, loss:0.50474460182683
# Epoch:197, w1:3.3005615427012738, w2:1.3995082239861236, bias:-2.194837267015835, loss:0.5044194818166445
# Epoch:198, w1:3.3121470707263097, w2:1.4000440603817699, bias:-2.200021434159806, loss:0.5040957046408313
# Epoch:199, w1:3.3237104722884028, w2:1.4005734534105203, bias:-2.205191467705532, loss:0.5037732634129207
# Epoch:200, w1:3.3352517737660565, w2:1.401096537327172, bias:-2.2103474822341638, loss:0.5034521513047525
# Epoch:201, w1:3.346771001998989, w2:1.4016134438463677, bias:-2.215489590584369, loss:0.5031323615452993
# Epoch:202, w1:3.3582681842777826, w2:1.4021243021899863, bias:-2.2206179038834635, loss:0.5028138874195315
# Epoch:203, w1:3.3697433483337167, w2:1.4026292391336188, bias:-2.2257325315779513, loss:0.5024967222673166
# Epoch:204, w1:3.381196522328773, w2:1.4031283790521494, bias:-2.2308335814634837, loss:0.5021808594823541
# Epoch:205, w1:3.3926277348458216, w2:1.4036218439644599, bias:-2.235921159714252, loss:0.5018662925111458
# Epoch:206, w1:3.404037014878974, w2:1.4041097535772757, bias:-2.2409953709118264, loss:0.5015530148519978
# Epoch:207, w1:3.4154243918241085, w2:1.4045922253281702, bias:-2.246056318073448, loss:0.5012410200540538
# Epoch:208, w1:3.4267898954695593, w2:1.4050693744277458, bias:-2.251104102679787, loss:0.5009303017163623
# Epoch:209, w1:3.4381335559869695, w2:1.405541313901008, bias:-2.2561388247021816, loss:0.5006208534869686
# Epoch:210, w1:3.449455403922303, w2:1.4060081546279481, bias:-2.26116058262936, loss:0.5003126690620385
# Epoch:211, w1:3.4607554701870167, w2:1.406470005383353, bias:-2.2661694734936626, loss:0.5000057421850083
# Epoch:212, w1:3.4720337860493826, w2:1.4069269728758544, bias:-2.271165592896771, loss:0.4997000666457618
# Epoch:213, w1:3.4832903831259667, w2:1.407379161786236, bias:-2.2761490350349556, loss:0.49939563627983236
# Epoch:214, w1:3.494525293373253, w2:1.4078266748050112, bias:-2.2811198927238485, loss:0.49909244496762944
# Epoch:215, w1:3.505738549079418, w2:1.4082696126692886, bias:-2.2860782574227554, loss:0.49879048663368925
# Epoch:216, w1:3.516930182856245, w2:1.4087080741989362, bias:-2.2910242192585106, loss:0.498489755245949
# Epoch:217, w1:3.528100227631186, w2:1.4091421563320616, bias:-2.2959578670488887, loss:0.4981902448150409
# Epoch:218, w1:3.539248716639557, w2:1.4095719541598213, bias:-2.3008792883255778, loss:0.49789194939361053
# Epoch:219, w1:3.550375683416873, w2:1.4099975609605697, bias:-2.3057885693567255, loss:0.49759486307565304
# Epoch:220, w1:3.5614811617913182, w2:1.4104190682333657, bias:-2.3106857951690665, loss:0.4972989799958709
# Epoch:221, w1:3.572565185876346, w2:1.410836565730845, bias:-2.3155710495696367, loss:0.4970042943290504
# Epoch:222, w1:3.5836277900634115, w2:1.4112501414914747, bias:-2.3204444151670858, loss:0.4967108002894557
# Epoch:223, w1:3.5946690090148308, w2:1.4116598818711987, bias:-2.325305973392592, loss:0.4964184921302421
# Epoch:224, w1:3.605688877656765, w2:1.4120658715744905, bias:-2.3301558045203934, loss:0.4961273641428854
# Epoch:225, w1:3.6166874311723283, w2:1.41246819368482, bias:-2.3349939876879335, loss:0.49583741065662784
# Epoch:226, w1:3.6276647049948183, w2:1.4128669296945506, bias:-2.3398206009156395, loss:0.4955486260379411
# Epoch:227, w1:3.638620734801064, w2:1.4132621595342743, bias:-2.3446357211263305, loss:0.49526100469000356
# Epoch:228, w1:3.6495555565048914, w2:1.4136539616015973, bias:-2.34943942416427, loss:0.4949745410521919
# Epoch:229, w1:3.6604692062507063, w2:1.4140424127893885, bias:-2.354231784813868, loss:0.49468922959959066
# Epoch:230, w1:3.6713617204071873, w2:1.4144275885134974, bias:-2.359012876818033, loss:0.4944050648425092
# Epoch:231, w1:3.6822331355610927, w2:1.4148095627399564, bias:-2.3637827728961933, loss:0.4941220413260195
# Epoch:232, w1:3.693083488511175, w2:1.4151884080116737, bias:-2.368541544761981, loss:0.4938401536295005
# Epoch:233, w1:3.7039128162622057, w2:1.4155641954746299, bias:-2.3732892631405935, loss:0.49355939636619867
# Epoch:234, w1:3.714721156019101, w2:1.4159369949035852, bias:-2.378025997785837, loss:0.4932797641827998
# Epoch:235, w1:3.725508545181159, w2:1.4163068747273089, bias:-2.3827518174968554, loss:0.49300125175901144
# Epoch:236, w1:3.7362750213363913, w2:1.4166739020533397, bias:-2.387466790134552, loss:0.4927238538071576
# Epoch:237, w1:3.7470206222559606, w2:1.4170381426922853, bias:-2.392170982637713, loss:0.4924475650717833
# Epoch:238, w1:3.757745385888715, w2:1.4173996611816715, bias:-2.396864461038835, loss:0.4921723803292709
# Epoch:239, w1:3.7684493503558203, w2:1.4177585208093473, bias:-2.4015472904796606, loss:0.49189829438746463
# Epoch:240, w1:3.7791325539454865, w2:1.418114783636458, bias:-2.4062195352264344, loss:0.49162530208530786
# Epoch:241, w1:3.7897950351077903, w2:1.4184685105199921, bias:-2.4108812586848773, loss:0.491353398292485
# Epoch:242, w1:3.8004368324495883, w2:1.4188197611349096, bias:-2.415532523414888, loss:0.4910825779090782
# Epoch:243, w1:3.811057984729522, w2:1.4191685939958627, bias:-2.420173391144979, loss:0.4908128358652279
# Epoch:244, w1:3.821658530853111, w2:1.4195150664785139, bias:-2.424803922786446, loss:0.49054416712080456
# Epoch:245, w1:3.8322385098679366, w2:1.419859234840461, bias:-2.429424178447283, loss:0.49027656666508823
# Epoch:246, w1:3.8427979609589085, w2:1.4202011542417754, bias:-2.434034217445842, loss:0.49001002951645495
# Epoch:247, w1:3.853336923443618, w2:1.4205408787651614, bias:-2.4386340983242443, loss:0.48974455072207196
# Epoch:248, w1:3.8638554367677758, w2:1.4208784614357448, bias:-2.443223878861552, loss:0.48948012535759927
# Epoch:249, w1:3.8743535405007288, w2:1.421213954240496, bias:-2.4478036160866967, loss:0.48921674852689956
# Epoch:250, w1:3.884831274331061, w2:1.4215474081472963, bias:-2.452373366291174, loss:0.48895441536175377
# Epoch:251, w1:3.8952886780622724, w2:1.421878873123653, bias:-2.456933185041511, loss:0.4886931210215834
# Epoch:252, w1:3.9057257916085346, w2:1.4222083981550702, bias:-2.4614831271915047, loss:0.4884328606931811
# Epoch:253, w1:3.916142654990525, w2:1.4225360312630833, bias:-2.4660232468942427, loss:0.4881736295904437
# Epoch:254, w1:3.926539308331336, w2:1.4228618195229608, bias:-2.470553597613903, loss:0.4879154229541158
# Epoch:255, w1:3.936915791852458, w2:1.4231858090810816, bias:-2.4750742321373433, loss:0.4876582360515355
# Epoch:256, w1:3.947272145869836, w2:1.423508045171995, bias:-2.47958520258548, loss:0.4874020641763876
# Epoch:257, w1:3.9576084107899967, w2:1.423828572135166, bias:-2.484086560424463, loss:0.4871469026484615
# Epoch:258, w1:3.967924627106248, w2:1.424147433431415, bias:-2.4885783564766473, loss:0.48689274681341443
# Epoch:259, w1:3.9782208353949455, w2:1.424464671659056, bias:-2.493060640931369, loss:0.48663959204254026
# Epoch:260, w1:3.9884970763118304, w2:1.4247803285697405, bias:-2.497533463355527, loss:0.4863874337325427
# Epoch:261, w1:3.998753390588431, w2:1.425094445084009, bias:-2.5019968727039728, loss:0.48613626730531256
# Epoch:262, w1:4.008989819028534, w2:1.4254070613065626, bias:-2.5064509173297163, loss:0.48588608820771184
# Epoch:263, w1:4.019206402504714, w2:1.4257182165412505, bias:-2.5108956449939464, loss:0.4856368919113594
# Epoch:264, w1:4.029403181954937, w2:1.426027949305788, bias:-2.5153311028758716, loss:0.4853886739124222
# Epoch:265, w1:4.039580198379217, w2:1.4263362973462028, bias:-2.519757337582386, loss:0.48514142973141233
# Epoch:266, w1:4.04973749283634, w2:1.4266432976510202, bias:-2.5241743951575604, loss:0.4848951549129843
# Epoch:267, w1:4.059875106440646, w2:1.4269489864651874, bias:-2.5285823210919647, loss:0.48464984502573993
# Epoch:268, w1:4.069993080358872, w2:1.4272533993037462, bias:-2.5329811603318215, loss:0.4844054956620349
# Epoch:269, w1:4.08009145580705, w2:1.427556570965254, bias:-2.5373709572879988, loss:0.4841621024377893
# Epoch:270, w1:4.090170274047473, w2:1.427858535544963, bias:-2.5417517558448397, loss:0.4839196609923018
# Epoch:271, w1:4.100229576385703, w2:1.4281593264477572, bias:-2.546123599368835, loss:0.4836781669880681
# Epoch:272, w1:4.110269404167646, w2:1.4284589764008566, bias:-2.5504865307171434, loss:0.48343761611059965
# Epoch:273, w1:4.1202897987766764, w2:1.4287575174662872, bias:-2.5548405922459545, loss:0.4831980040682508
# Epoch:274, w1:4.13029080163082, w2:1.4290549810531266, bias:-2.559185825818708, loss:0.48295932659204355
# Epoch:275, w1:4.140272454179983, w2:1.429351397929526, bias:-2.563522272814164, loss:0.48272157943549876
# Epoch:276, w1:4.150234797903241, w2:1.4296467982345147, bias:-2.56784997413433, loss:0.48248475837446864
# Epoch:277, w1:4.1601778743061715, w2:1.4299412114895886, bias:-2.5721689702122466, loss:0.48224885920697375
# Epoch:278, w1:4.170101724918245, w2:1.4302346666100902, bias:-2.5764793010196354, loss:0.48201387775304033
# Epoch:279, w1:4.1800063912902585, w2:1.4305271919163807, bias:-2.5807810060744116, loss:0.48177980985454183
# Epoch:280, w1:4.189891914991821, w2:1.4308188151448098, bias:-2.585074124448061, loss:0.48154665137504266
# Epoch:281, w1:4.1997583376088885, w2:1.4311095634584872, bias:-2.5893586947728884, loss:0.4813143981996458
# Epoch:282, w1:4.209605700741341, w2:1.431399463457857, bias:-2.593634755249137, loss:0.48108304623483883
# Epoch:283, w1:4.219434046000614, w2:1.4316885411910836, bias:-2.5979023436519797, loss:0.4808525914083477
# Epoch:284, w1:4.229243415007364, w2:1.4319768221642455, bias:-2.602161497338391, loss:0.48062302966898773
# Epoch:285, w1:4.239033849389193, w2:1.4322643313513477, bias:-2.606412253253892, loss:0.4803943569865202
# Epoch:286, w1:4.248805390778403, w2:1.4325510932041512, bias:-2.610654647939178, loss:0.4801665693515103
# Epoch:287, w1:4.258558080809808, w2:1.432837131661825, bias:-2.6148887175366333, loss:0.47993966277518535
# Epoch:288, w1:4.26829196111857, w2:1.4331224701604228, bias:-2.6191144977967236, loss:0.47971363328929756
# Epoch:289, w1:4.278007073338101, w2:1.43340713164219, bias:-2.623332024084281, loss:0.4794884769459873
# Epoch:290, w1:4.2877034590979815, w2:1.433691138564699, bias:-2.627541331384675, loss:0.47926418981764857
# Epoch:291, w1:4.29738116002194, w2:1.4339745129098238, bias:-2.631742454309878, loss:0.47904076799679635
# Epoch:292, w1:4.307040217725858, w2:1.4342572761925483, bias:-2.6359354271044197, loss:0.47881820759593513
# Epoch:293, w1:4.3166806738158225, w2:1.4345394494696173, bias:-2.6401202836512403, loss:0.47859650474743076
# Epoch:294, w1:4.326302569886212, w2:1.4348210533480317, bias:-2.6442970574774396, loss:0.478375655603382
# Epoch:295, w1:4.335905947517825, w2:1.435102107993388, bias:-2.6484657817599233, loss:0.478155656335495
# Epoch:296, w1:4.345490848276043, w2:1.4353826331380704, bias:-2.6526264893309532, loss:0.4779365031349594
# Epoch:297, w1:4.355057313709028, w2:1.435662648089291, bias:-2.6567792126835976, loss:0.4777181922123246
# Epoch:298, w1:4.3646053853459605, w2:1.4359421717369882, bias:-2.660923983977086, loss:0.4775007197973791
# Epoch:299, w1:4.37413510469531, w2:1.4362212225615816, bias:-2.6650608350420715, loss:0.4772840821390317
# Epoch:300, w1:4.383646513243143, w2:1.4364998186415854, bias:-2.6691897973858, loss:0.47706827550519065
# Epoch:301, w1:4.3931396524514605, w2:1.4367779776610863, bias:-2.673310902197188, loss:0.4768532961826498
# Epoch:302, w1:4.402614563756575, w2:1.4370557169170854, bias:-2.6774241803518137, loss:0.47663914047697004
# Epoch:303, w1:4.412071288567513, w2:1.4373330533267088, bias:-2.681529662416819, loss:0.4764258047123667
# Epoch:304, w1:4.421509868264461, w2:1.4376100034342858, bias:-2.6856273786557256, loss:0.4762132852315968
# Epoch:305, w1:4.430930344197231, w2:1.4378865834183021, bias:-2.689717359033169, loss:0.47600157839584517
# Epoch:306, w1:4.440332757683768, w2:1.4381628090982264, bias:-2.693799633219547, loss:0.4757906805846165
# Epoch:307, w1:4.449717150008681, w2:1.4384386959412137, bias:-2.6978742305955894, loss:0.475580588195624
# Epoch:308, w1:4.459083562421808, w2:1.4387142590686877, bias:-2.701941180256848, loss:0.47537129764468217
# Epoch:309, w1:4.468432036136813, w2:1.4389895132628057, bias:-2.706000511018105, loss:0.47516280536559924
# Epoch:310, w1:4.477762612329803, w2:1.4392644729728052, bias:-2.7100522514177112, loss:0.47495510781007105
# Epoch:311, w1:4.487075332137989, w2:1.439539152321238, bias:-2.71409642972184, loss:0.4747482014475768
# Epoch:312, w1:4.49637023665836, w2:1.43981356511009, bias:-2.7181330739286755, loss:0.4745420827652739
# Epoch:313, w1:4.505647366946396, w2:1.440087724826793, bias:-2.722162211772523, loss:0.4743367482678963
# Epoch:314, w1:4.5149067640148, w2:1.440361644650125, bias:-2.72618387072785, loss:0.4741321944776521
# Epoch:315, w1:4.524148468832265, w2:1.4406353374560084, bias:-2.7301980780132564, loss:0.4739284179341222
# Epoch:316, w1:4.533372522322263, w2:1.4409088158231993, bias:-2.7342048605953755, loss:0.47372541519416084
# Epoch:317, w1:4.542578965361859, w2:1.4411820920388783, bias:-2.738204245192708, loss:0.4735231828317966
# Epoch:318, w1:4.551767838780553, w2:1.4414551781041371, bias:-2.7421962582793906, loss:0.47332171743813395
# Epoch:319, w1:4.56093918335915, w2:1.441728085739369, bias:-2.746180926088897, loss:0.4731210156212557
# Epoch:320, w1:4.570093039828645, w2:1.442000826389561, bias:-2.7501582746176756, loss:0.4729210740061275
# Epoch:321, w1:4.579229448869144, w2:1.44227341122949, bias:-2.7541283296287267, loss:0.4727218892345016
# Epoch:322, w1:4.588348451108802, w2:1.4425458511688274, bias:-2.758091116655114, loss:0.4725234579648221
# Epoch:323, w1:4.597450087122783, w2:1.4428181568571499, bias:-2.7620466610034184, loss:0.4723257768721317
# Epoch:324, w1:4.606534397432254, w2:1.4430903386888605, bias:-2.7659949877571317, loss:0.4721288426479774
# Epoch:325, w1:4.615601422503387, w2:1.4433624068080213, bias:-2.76993612177999, loss:0.4719326520003197
# Epoch:326, w1:4.624651202746391, w2:1.4436343711130992, bias:-2.7738700877192524, loss:0.47173720165343946
# Epoch:327, w1:4.633683778514571, w2:1.443906241261626, bias:-2.7777969100089206, loss:0.4715424883478482
# Epoch:328, w1:4.642699190103395, w2:1.4441780266747735, bias:-2.7817166128729065, loss:0.47134850884019774
# Epoch:329, w1:4.651697477749597, w2:1.4444497365418485, bias:-2.7856292203281403, loss:0.47115525990319046
# Epoch:330, w1:4.660678681630289, w2:1.444721379824705, bias:-2.789534756187631, loss:0.4709627383254912
# Epoch:331, w1:4.669642841862103, w2:1.444992965262077, bias:-2.7934332440634693, loss:0.4707709409116383
# Epoch:332, w1:4.678589998500346, w2:1.4452645013738343, bias:-2.7973247073697824, loss:0.4705798644819579
# Epoch:333, w1:4.687520191538176, w2:1.445535996465161, bias:-2.8012091693256367, loss:0.47038950587247524
# Epoch:334, w1:4.696433460905802, w2:1.4458074586306582, bias:-2.805086652957891, loss:0.47019986193483093
# Epoch:335, w1:4.7053298464696995, w2:1.4460788957583737, bias:-2.808957181104, loss:0.470010929536194
# Epoch:336, w1:4.714209388031844, w2:1.4463503155337587, bias:-2.812820776414773, loss:0.46982270555917754
# Epoch:337, w1:4.723072125328966, w2:1.446621725443553, bias:-2.81667746135708, loss:0.4696351869017546
# Epoch:338, w1:4.731918098031819, w2:1.4468931327796002, bias:-2.8205272582165177, loss:0.4694483704771756
# Epoch:339, w1:4.7407473457444755, w2:1.4471645446425951, bias:-2.824370189100025, loss:0.46926225321388415
# Epoch:340, w1:4.7495599080036275, w2:1.447435967945762, bias:-2.828206275938457, loss:0.46907683205543527
# Epoch:341, w1:4.7583558242779125, w2:1.4477074094184674, bias:-2.832035540489114, loss:0.46889210396041375
# Epoch:342, w1:4.767135133967257, w2:1.4479788756097682, bias:-2.835858004338227, loss:0.46870806590235325
# Epoch:343, w1:4.775897876402232, w2:1.4482503728918945, bias:-2.8396736889034018, loss:0.46852471486965536
# Epoch:344, w1:4.784644090843426, w2:1.448521907463671, bias:-2.8434826154360215, loss:0.46834204786550954
# Epoch:345, w1:4.793373816480838, w2:1.448793485353876, bias:-2.847284805023607, loss:0.4681600619078138
# Epoch:346, w1:4.8020870924332835, w2:1.4490651124245395, bias:-2.8510802785921396, loss:0.46797875402909583
# Epoch:347, w1:4.810783957747811, w2:1.4493367943741828, bias:-2.854869056908342, loss:0.46779812127643444
# Epoch:348, w1:4.819464451399145, w2:1.4496085367409985, bias:-2.858651160581921, loss:0.46761816071138135
# Epoch:349, w1:4.828128612289134, w2:1.4498803449059738, bias:-2.862426610067775, loss:0.46743886940988466
# Epoch:350, w1:4.836776479246218, w2:1.450152224095957, bias:-2.866195425668159, loss:0.4672602444622111
# Epoch:351, w1:4.845408091024912, w2:1.4504241793866695, bias:-2.8699576275348186, loss:0.4670822829728701
# Epoch:352, w1:4.8540234863052945, w2:1.4506962157056615, bias:-2.873713235671084, loss:0.4669049820605377
# Epoch:353, w1:4.862622703692523, w2:1.4509683378352174, bias:-2.87746226993393, loss:0.4667283388579815
# Epoch:354, w1:4.871205781716354, w2:1.4512405504152053, bias:-2.881204750036001, loss:0.46655235051198524
# Epoch:355, w1:4.879772758830678, w2:1.4515128579458771, bias:-2.8849406955476042, loss:0.4663770141832746
# Epoch:356, w1:4.888323673413074, w2:1.4517852647906178, bias:-2.888670125898664, loss:0.4662023270464431
# Epoch:357, w1:4.896858563764368, w2:1.4520577751786443, bias:-2.8923930603806483, loss:0.4660282862898791
# Epoch:358, w1:4.905377468108206, w2:1.4523303932076561, bias:-2.896109518148462, loss:0.465854889115692
# Epoch:359, w1:4.913880424590649, w2:1.452603122846438, bias:-2.899819518222306, loss:0.4656821327396398
# Epoch:360, w1:4.922367471279766, w2:1.4528759679374152, bias:-2.9035230794895064, loss:0.4655100143910571
# Epoch:361, w1:4.9308386461652525, w2:1.4531489321991626, bias:-2.9072202207063147, loss:0.4653385313127837
# Epoch:362, w1:4.93929398715805, w2:1.4534220192288685, bias:-2.910910960499675, loss:0.4651676807610927
# Epoch:363, w1:4.947733532089983, w2:1.453695232504754, bias:-2.9145953173689634, loss:0.4649974600056195
# Epoch:364, w1:4.95615731871341, w2:1.4539685753884484, bias:-2.918273309687699, loss:0.4648278663292922
# Epoch:365, w1:4.964565384700875, w2:1.4542420511273209, bias:-2.9219449557052246, loss:0.46465889702826063
# Epoch:366, w1:4.972957767644786, w2:1.4545156628567713, bias:-2.9256102735483585, loss:0.4644905494118276
# Epoch:367, w1:4.981334505057089, w2:1.454789413602478, bias:-2.9292692812230228, loss:0.46432282080237924
# Epoch:368, w1:4.989695634368961, w2:1.455063306282606, bias:-2.9329219966158413, loss:0.4641557085353158
# Epoch:369, w1:4.998041192930514, w2:1.4553373437099748, bias:-2.9365684374957115, loss:0.46398920995898424
# Epoch:370, w1:5.0063712180105036, w2:1.4556115285941864, bias:-2.9402086215153505, loss:0.4638233224346095
# Epoch:371, w1:5.014685746796055, w2:1.4558858635437153, bias:-2.9438425662128154, loss:0.46365804333622707
# Epoch:372, w1:5.022984816392393, w2:1.4561603510679597, bias:-2.947470289012999, loss:0.46349337005061586
# Epoch:373, w1:5.031268463822582, w2:1.4564349935792564, bias:-2.9510918072291, loss:0.4633292999772319
# Epoch:374, w1:5.039536726027283, w2:1.4567097933948594, bias:-2.9547071380640686, loss:0.46316583052814014
# Epoch:375, w1:5.04778963986451, w2:1.4569847527388802, bias:-2.9583162986120293, loss:0.4630029591279508

# %% [markdown]
# ### Now weights and Bias from the Model

# %%
print(w1,w2,b)
# Out:
# 5.04778963986451 1.4569847527388802 -2.9583162986120293
